# %%
## Load Packages

# system
from pathlib import Path
import sys

# external software
import yaml

# python internal
import pandas as pd
from datetime import date
from importlib.metadata import version
from datetime import date
from importlib.metadata import version

# Project Packages
from ir_pell_accepts.io_utils import infer_and_read_file
from ir_pell_accepts.paths import CONFIG_PATH
from ir_pell_accepts.headcount_calcs import grs_cohort_pell, grs_cohort, total_headcount, fall_enrollment
from ir_pell_accepts.clean import remove_leading_zeros
from ir_pell_accepts.helper import calc_percent, calc_academic_year_from_term, construct_cohort
from ir_pell_accepts.output import output_results, contruct_results_df

# %%
## Jupyter-Notebook Only -- comment-out when creating .py script

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_seq_items', 1000)

# %%
## Load Configuration File and store its values

# Check for config file
if not CONFIG_PATH.exists():
    raise FileNotFoundError(
        f"Config file not found at {CONFIG_PATH}. "
        "Create ir-<project>-<name>/configs/config.yaml to execute code"
    )

with CONFIG_PATH.open("r") as f:
    config = yaml.safe_load(f)

# File and folder paths
BOX_ROOT = Path(config["box_repo"]["root"]).expanduser()
DIR = Path(config["box_repo"]["pell_dir"]).expanduser()
PELL_PATH = DIR / Path(config["box_repo"]["pell_file"]).expanduser()
RETENTION_PATH = Path(config["box_repo"]["retention_dir"]).expanduser() / Path(config["box_repo"]["retention_file"]).expanduser()
ENROLLMENT_PATH = Path(config["box_repo"]["enrollment_dir"]).expanduser() / Path(config["box_repo"]["enrollment_file"]).expanduser()
RESULTS_PATH = Path(config["box_repo"]["results_dir"]) / Path(config["box_repo"]["results_file"])

# Project Parameters
term = config["params"]["term"] 
id_column = config["params"]["id_column"]

# %%
# Test configuation inputs
if not BOX_ROOT.exists():
    raise FileNotFoundError(f"Box repo path does not exist: {BOX_ROOT}")

if not DIR.exists():
    raise FileNotFoundError(f"path does not exist: {DIR}")

if not PELL_PATH.exists():
    raise FileNotFoundError(f"Input Pell file does not exist: {PELL_PATH}")

if not RETENTION_PATH.exists():
    raise FileNotFoundError(f"Input Retention file does not exist: {RETENTION_PATH}")

if not ENROLLMENT_PATH.exists():
    raise FileNotFoundError(f"Input Retention file does not exist: {ENROLLMENT_PATH}")

if not RESULTS_PATH.parent.exists():
    raise FileNotFoundError(f"Results path does not exist: {RESULTS_PATH.parent}")

if len(term) != 6:
    raise ValueError(f"Value for term, {term}, is invalid. Needs to be a 6 digit numeric. Ex: '202580'")

# %%
# Read in files (all columns coverted to strings)
df_pell = infer_and_read_file(PELL_PATH)
df_ret  = infer_and_read_file(RETENTION_PATH)
df_enrl = infer_and_read_file(ENROLLMENT_PATH)

# %%
# Standardize ID column
df_pell = remove_leading_zeros(df_pell, column=id_column)
df_ret  = remove_leading_zeros(df_ret, column=id_column)
df_enrl = remove_leading_zeros(df_enrl, column=id_column)

# %%
aid_year_column = 'AID_YEAR'
cohort_column = 'Cohort Name'
aid_year = calc_academic_year_from_term(term)
cohort = construct_cohort(term)
print(aid_year)
print(cohort)
# Out:
# 2526
# 2025 Fall, First-Time, Full-Time

# %%
pids = df_pell.loc[df_pell[aid_year_column] == aid_year, id_column]
rids = df_ret.loc[df_ret[cohort_column] == cohort, id_column]

# %%
len(set(pids) & set(rids))
# Out:
# 343

# %%
dfe = df_enrl
dfp = df_pell
dfr = df_ret

# %%
enrollment_conditions = (
        (dfe['Academic Period'] == term) &
        (dfe['Time Status'] == 'FT') &
        (dfe['Student Level'] == 'UG') &
        (dfe['Degree'] != 'Non Degree')
    )

# %%
incoming_transfer_cohort = term[0:4] + " " + "Fall, Transfer, Full-Time"

# %%
pids = dfp.loc[dfp['AID_YEAR'] == aid_year, id_column].dropna()
eids = dfe.loc[enrollment_conditions, id_column].dropna()
rids = dfr.loc[dfr['Cohort Name'] != incoming_transfer_cohort, id_column].dropna()
rids_t = dfr.loc[dfr['Cohort Name'] == incoming_transfer_cohort, id_column].dropna()

# %%
dfp_t = dfp[dfp['AID_YEAR'] == aid_year]

# %%
print(dfp_t.head())
print(dfp_t.shape)
# Out:
#               ID AID_YEAR
# 13699  100057265     2526
# 13700  101195564     2526
# 13701  101300108     2526
# 13702  101310537     2526
# 13703  101312434     2526
# (1310, 2)

# %%
dfp_t2 = dfp_t.merge(dfr[['ID', 'Academic Period 1st Fall', 'Cohort Type Description']], on='ID', how='left')

# %%
dfp_t2.shape
# Out:
# (1310, 4)

# %%
dfp_t2.head()
# Out:
#           ID AID_YEAR Academic Period 1st Fall      Cohort Type Description
# 0  100057265     2526                   202480  Fall, First-Time, Full-Time
# 1  101195564     2526                      NaN  Spring, Transfer, Full-Time
# 2  101300108     2526                      NaN  Spring, Transfer, Full-Time
# 3  101310537     2526                      NaN  Spring, Transfer, Part-Time
# 4  101312434     2526                      NaN  Spring, Transfer, Full-Time

# %%
dfp_t2['Academic Period 1st Fall'].value_counts()
# Out:
# Academic Period 1st Fall
# 202580    399
# 202480    300
# 202380    255
# 202280    245
# 202180     49
# 202080     12
# 201980      7
# 201780      2
# Name: count, dtype: int64

# %%
dfe_t = dfe[enrollment_conditions]

# %%
dfe_t.shape
# Out:
# (6939, 35)

# %%
dfe_t2 = dfe_t.merge(dfr[['ID', 'Academic Period 1st Fall', 'Cohort Name']], on='ID', how='left')

# %%
dfe_t2.head()
# Out:
#   Academic Period Address Start Date (most recent address)     CIP  \
# 0          202580                   10/25/2021 12:00:00 AM  140801
# 1          202580                   12/21/2022 12:00:00 AM  141001
# 2          202580                   10/27/2021 12:00:00 AM  141001
# 3          202580                   11/30/2021 12:00:00 AM  141901
# 4          202580                   10/25/2020 12:00:00 AM  141901
#
#   City (most recent address)         College/School College/School Code  \
# 0                      Dover  School of Engineering                  EN
# 1               New Carlisle  School of Engineering                  EN
# 2                 Miamisburg  School of Engineering                  EN
# 3                Saint Louis  School of Engineering                  EN
# 4           Liberty Township  School of Engineering                  EN
#
#   County Code (most recent address) County Desc (most recent address)  \
# 0                             39157                     OH-Tuscarawas
# 1                             39023                          OH-Clark
# 2                             39113                     OH-Montgomery
# 3                             29510               MO-Saint Louis City
# 4                             39017                         OH-Butler
#
#                           Degree             Department/Area Dept/Area Code  \
# 0  Bachelor of Civil Engineering  Civil & Env Engr Engr Mech            CEE
# 1   Bachelor of Electrical Engr.  Electrical & Computer Engr            ECE
# 2   Bachelor of Electrical Engr.  Electrical & Computer Engr            ECE
# 3   Bachelor of Mechanical Engr.      Mechanical Engineering            MAE
# 4   Bachelor of Mechanical Engr.      Mechanical Engineering            MAE
#
#   Gender         ID INDI in Academic Period Starting Fall 2025  \
# 0    Men  101718675                                        NaN
# 1    Men  101717962                                        NaN
# 2    Men  101713201                                        NaN
# 3    Men  101719002                                        NaN
# 4    Men  101686551                                        NaN
#
#                     Major Major Code               Name  \
# 0       Civil Engineering        CEE   Williams, Dawson
# 1  Electrical Engineering        ELE     Locke, Noah D.
# 2  Electrical Engineering        ELE  Wells, Matthew M.
# 3  Mechanical Engineering        MEE  Murphy, Elijah M.
# 4  Mechanical Engineering        MEE   Collett, Kyle S.
#
#   Nation (most recent address) Nation Desc (most recent address)  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
#
#   Nation Of Citizenship Desc Nation Of Citizenship Desc (susan's data)  \
# 0                        NaN                                       NaN
# 1                        NaN                                       NaN
# 2                        NaN                                       NaN
# 3                        NaN                                       NaN
# 4                        NaN                                       NaN
#
#   Permanent Residence State/Nation Postal Code (most recent address)  \
# 0                               OH                        44622-9617
# 1                               OH                        45344-9571
# 2                               OH                        45342-1456
# 3                               MO                        63109-3536
# 4                               OH                        45044-5779
#
#   Raceethnicity    Religion State Province (most recent address)  \
# 0         White  Protestant                                   OH
# 1         White  Protestant                                   OH
# 2         White  Protestant                                   OH
# 3         White  Protestant                                   MO
# 4         White  Protestant                                   OH
#
#   State Province Desc (most recent address)  \
# 0                                      Ohio
# 1                                      Ohio
# 2                                      Ohio
# 3                                  Missouri
# 4                                      Ohio
#
#   Street Line1 (most recent address) Student Level Time Status  \
# 0               8933 Sandstone Rd NE            UG          FT
# 1                  12330 Stafford Rd            UG          FT
# 2         5281 Soldiers Home Msbg Rd            UG          FT
# 3                    4945 Finkman St            UG          FT
# 4                      5888 Alder Ct            UG          FT
#
#   UDSA in Academic Period (Starting Fall 2025) UG/LW Class  \
# 0                                          NaN      Senior
# 1                                          NaN      Senior
# 2                                          NaN      Senior
# 3                                          NaN      Senior
# 4                                          NaN      Senior
#
#   Course Billing Credits Person Uid Person Uid (UD Person)  \
# 0                     12    1925336                1925336
# 1                     12    1924612                1924612
# 2                     12    1919831                1919831
# 3                     12    1925664                1925664
# 4                     12    1893043                1893043
#
#   Academic Period 1st Fall                       Cohort Name
# 0                   202280  2022 Fall, First-Time, Full-Time
# 1                   202280  2022 Fall, First-Time, Full-Time
# 2                   202280  2022 Fall, First-Time, Full-Time
# 3                   202280  2022 Fall, First-Time, Full-Time
# 4                   202180  2021 Fall, First-Time, Full-Time

# %%
sum(dfe_t2['Cohort Name'].isna())
# Out:
# 12

# %%
dfe_t2b = dfe_t2[dfe_t2['Cohort Name'].isna()]

# %%
dfe_t2b
# Out:
#      Academic Period Address Start Date (most recent address)     CIP  \
# 323           202580                    10/6/2021 12:00:00 AM  150805
# 2394          202580                   10/25/2020 12:00:00 AM  230101
# 4389          202580                    1/12/2022 12:00:00 AM  110101
# 4521          202580                     7/2/1925 12:00:00 AM  380101
# 4522          202580                     7/2/2025 12:00:00 AM  380101
# 4523          202580                     7/2/2025 12:00:00 AM  380101
# 4524          202580                     7/2/2025 12:00:00 AM  380101
# 4525          202580                     8/4/2022 12:00:00 AM  380101
# 5404          202580                     9/5/2021 12:00:00 AM  150805
# 5449          202580                      4/7/2025 2:34:28 PM  141901
# 5989          202580                   11/21/2022 12:00:00 AM  240102
# 6184          202580                     4/16/2024 2:07:18 PM  110701
#
#      City (most recent address)              College/School  \
# 323                      Dayton       School of Engineering
# 2394                    Oakwood  College of Arts & Sciences
# 4389                     Dayton  College of Arts & Sciences
# 4521                  Bangalore  College of Arts & Sciences
# 4522                  Bangalore  College of Arts & Sciences
# 4523                  Bangalore  College of Arts & Sciences
# 4524                  Bangalore  College of Arts & Sciences
# 4525                  Bangalore  College of Arts & Sciences
# 5404                  Englewood       School of Engineering
# 5449                     Dayton       School of Engineering
# 5989              Spring Valley  College of Arts & Sciences
# 6184                Beavercreek  College of Arts & Sciences
#
#      College/School Code County Code (most recent address)  \
# 323                   EN                             39113
# 2394                  AS                             39113
# 4389                  AS                             39113
# 4521                  AS                               NaN
# 4522                  AS                               NaN
# 4523                  AS                               NaN
# 4524                  AS                               NaN
# 4525                  AS                               NaN
# 5404                  EN                             39113
# 5449                  EN                             39113
# 5989                  AS                             39057
# 6184                  AS                             39057
#
#      County Desc (most recent address)                        Degree  \
# 323                      OH-Montgomery  BS in Engineering Technology
# 2394                     OH-Montgomery              Bachelor of Arts
# 4389                     OH-Montgomery           Bachelor of Science
# 4521                               NaN              Bachelor of Arts
# 4522                               NaN              Bachelor of Arts
# 4523                               NaN              Bachelor of Arts
# 4524                               NaN              Bachelor of Arts
# 4525                               NaN              Bachelor of Arts
# 5404                     OH-Montgomery  BS in Engineering Technology
# 5449                     OH-Montgomery  Bachelor of Mechanical Engr.
# 5989                         OH-Greene   Bachelor of General Studies
# 6184                         OH-Greene           Bachelor of Science
#
#              Department/Area Dept/Area Code Gender         ID  \
# 323   Engineering Technology            EGT    Men  101713264
# 2394                 English            ENG    Men  101688785
# 4389        Computer Science            CPS    Men  101704893
# 4521              Philosophy            PHL    Men  101892431
# 4522              Philosophy            PHL    Men  101892432
# 4523              Philosophy            PHL    Men  101892433
# 4524              Philosophy            PHL    Men  101892434
# 4525              Philosophy            PHL    Men  101750217
# 5404  Engineering Technology            EGT    Men  101714314
# 5449  Mechanical Engineering            MAE    Men    3940724
# 5989         General Studies            GEN  Women    2789265
# 6184        Computer Science            CPS  Women  101599721
#
#      INDI in Academic Period Starting Fall 2025                         Major  \
# 323                                         NaN   Mechanical Engineering Tech
# 2394                                        NaN                       English
# 4389                                        NaN  Computer Information Systems
# 4521                India Students (Marianists)                    Philosophy
# 4522                India Students (Marianists)                    Philosophy
# 4523                India Students (Marianists)                    Philosophy
# 4524                India Students (Marianists)                    Philosophy
# 4525                India Students (Marianists)                    Philosophy
# 5404                                        NaN   Mechanical Engineering Tech
# 5449                                        NaN        Mechanical Engineering
# 5989                                        NaN               General Studies
# 6184                                        NaN              Computer Science
#
#      Major Code                  Name Nation (most recent address)  \
# 323         MCT  Joseph, Alexander M.                          NaN
# 2394        ENG      Hamid, Shiraz R.                          NaN
# 4389        CIS    Rubuto, Gislain G.                          NaN
# 4521        PHL          Soreng, Ajay                           IN
# 4522        PHL        Mariaya, Rahul                           IN
# 4523        PHL      Xalxo, Tej Kumar                           IN
# 4524        PHL        Kujur, Wilfred                           IN
# 4525        PHL   Kiran Kumar, Chilka                           IN
# 5404        MCT    Hartman, Keaton R.                          NaN
# 5449        MEE      Brailer, Evan G.                           US
# 5989        GEN     Connor, Lauren A.                          NaN
# 6184        CPS         Morrison, Joy                           US
#
#      Nation Desc (most recent address) Nation Of Citizenship Desc  \
# 323                                NaN                        NaN
# 2394                               NaN                        NaN
# 4389                               NaN                        NaN
# 4521                             India                        NaN
# 4522                             India                        NaN
# 4523                             India                        NaN
# 4524                             India                        NaN
# 4525                             India                        NaN
# 5404                               NaN                        NaN
# 5449                     United States                        NaN
# 5989                               NaN                        NaN
# 6184                     United States                        NaN
#
#      Nation Of Citizenship Desc (susan's data)  \
# 323                                        NaN
# 2394                                       NaN
# 4389                                       NaN
# 4521                                       NaN
# 4522                                       NaN
# 4523                                       NaN
# 4524                                       NaN
# 4525                                       NaN
# 5404                                       NaN
# 5449                                       NaN
# 5989                                       NaN
# 6184                                       NaN
#
#      Permanent Residence State/Nation Postal Code (most recent address)  \
# 323                                OH                        45405-4214
# 2394                               OH                        45419-3330
# 4389                               OH                        45404-2241
# 4521                            India                             56009
# 4522                            India                            560099
# 4523                            India                            560099
# 4524                            India                            560099
# 4525                            India                             56099
# 5404                               OH                        45322-1305
# 5449                               OH                        45402-1655
# 5989                               OH                        45370-9703
# 6184                               OH                        45431-3649
#
#                   Raceethnicity        Religion  \
# 323           Two or More Races         Unknown
# 2394                      Asian           Other
# 4389  Black or African American         Unknown
# 4521                    Unknown             NaN
# 4522                    Unknown             NaN
# 4523                    Unknown             NaN
# 4524                    Unknown             NaN
# 4525                    Unknown             NaN
# 5404                   Hispanic  Roman Catholic
# 5449                      White         Unknown
# 5989                      White   No Preference
# 6184  Black or African American      Protestant
#
#      State Province (most recent address)  \
# 323                                    OH
# 2394                                   OH
# 4389                                   OH
# 4521                                  NaN
# 4522                                  NaN
# 4523                                  NaN
# 4524                                  NaN
# 4525                                  NaN
# 5404                                   OH
# 5449                                   OH
# 5989                                   OH
# 6184                                   OH
#
#      State Province Desc (most recent address)  \
# 323                                       Ohio
# 2394                                      Ohio
# 4389                                      Ohio
# 4521                                       NaN
# 4522                                       NaN
# 4523                                       NaN
# 4524                                       NaN
# 4525                                       NaN
# 5404                                      Ohio
# 5449                                      Ohio
# 5989                                      Ohio
# 6184                                      Ohio
#
#      Street Line1 (most recent address) Student Level Time Status  \
# 323                      1100 N Main St            UG          FT
# 2394                 28 Thruston Blvd W            UG          FT
# 4389                      407 Brandt St            UG          FT
# 4521                 Deepahalli College            UG          FT
# 4522                 Deepahalli College            UG          FT
# 4523                 Deepahalli College            UG          FT
# 4524                 Deepahalli College            UG          FT
# 4525   Deepahalli, Post Bag 1 Ghandpura            UG          FT
# 5404                      624 N Main St            UG          FT
# 5449              340 E 1st St Unit 630            UG          FT
# 5989                2725 River Bluff Dr            UG          FT
# 6184              2392 Mallard Ln Apt 7            UG          FT
#
#      UDSA in Academic Period (Starting Fall 2025) UG/LW Class  \
# 323                                           NaN      Senior
# 2394                                          NaN      Junior
# 4389                                          NaN      Senior
# 4521                                          NaN    Freshman
# 4522                                          NaN    Freshman
# 4523                                          NaN    Freshman
# 4524                                          NaN    Freshman
# 4525                                          NaN      Senior
# 5404                                          NaN      Senior
# 5449                                          NaN      Senior
# 5989                                          NaN      Senior
# 6184                                          NaN      Senior
#
#      Course Billing Credits Person Uid Person Uid (UD Person)  \
# 323                      18    1919894                1919894
# 2394                     12    1895282                1895282
# 4389                     18    1911447                1911447
# 4521                     19    2099703                2099703
# 4522                     19    2099704                2099704
# 4523                     19    2099705                2099705
# 4524                     19    2099706                2099706
# 4525                     13    1956981                1956981
# 5404                     18    1920952                1920952
# 5449                     16     486313                 486313
# 5989                     12    1206217                1206217
# 6184                     12    1805723                1805723
#
#      Academic Period 1st Fall Cohort Name
# 323                       NaN         NaN
# 2394                      NaN         NaN
# 4389                      NaN         NaN
# 4521                      NaN         NaN
# 4522                      NaN         NaN
# 4523                      NaN         NaN
# 4524                      NaN         NaN
# 4525                      NaN         NaN
# 5404                      NaN         NaN
# 5449                      NaN         NaN
# 5989                      NaN         NaN
# 6184                      NaN         NaN

# %%
dfr[dfr['ID'].isin(dfe_t2b['ID'])]
# Out:
# Empty DataFrame
# Columns: [Academic Period 1st Fall, Academic Period 1st Spring, Academic Period 2nd Fall, Academic Period 2nd Spring, Academic Period 3rd Fall, Academic Period 3rd Spring, Academic Period 4th Fall, Academic Period 4th Spring, Academic Period 5th Fall, Academic Period 6th Fall, Academic Period 6th Spring, Academic Period 7th Fall, Academic Period 8th Fall, Academic Period 9th Fall, Academic Period 9th Spring, Academic Period Graduation, Academic Period5th Spring, Academic Period7th Spring, Academic Period8th Spring, Academic Standing Desc 1st Fall, Academic Standing Desc 1st Spring, Academic Standing Desc 2nd Fall, Academic Standing Desc 2nd Spring, Academic Standing Desc 3rd Fall, Academic Standing Desc 3rd Spring, Academic Standing Desc 4th Fall, Academic Standing Desc 4th Spring, Academic Standing Desc 5th Fall, Academic Standing Desc 6th Fall, Academic Standing Desc 6th Spring, Academic Standing Desc 7th Fall, Academic Standing Desc 8th Fall, Academic Standing Desc 9th Fall, Academic Standing Desc 9th Spring, Academic Standing Desc5th Spring, Academic Standing Desc7th Spring, Academic Standing Desc8th Spring, Cohort, Cohort Academic Period, Cohort Desc, Cohort Fiscal Year, Cohort Name, Cohort Season, Cohort Start Date (for IPEDS Graduation Versions), Cohort Start Term Name, Cohort Start Terms, Cohort Time Status, Cohort Transfer Status, Cohort Type, Cohort Type Description, Deceased Date, Deceased Date 1st Fall, Deceased Date 1st Spring, Deceased Date 2nd Fall, Deceased Date 2nd Spring, Deceased Date 3rd Fall, Deceased Date 3rd Spring, Deceased Date 4th Fall, Deceased Date 4th Spring, Deceased Date 5th Fall, Deceased Date 6th Fall, Deceased Date 6th Spring, Deceased Date 7th Fall, Deceased Date 8th Fall, Deceased Date 9th Fall, Deceased Date 9th Spring, Deceased Date5th Spring, Deceased Date7th Spring, Deceased Date8th Spring, Deceased Status, Deceased Status 1st Fall, Deceased Status 1st Spring, Deceased Status 2nd Fall, Deceased Status 2nd Spring, Deceased Status 3rd Fall, Deceased Status 3rd Spring, Deceased Status 4th Fall, Deceased Status 4th Spring, Deceased Status 5th Fall, Deceased Status 6th Fall, Deceased Status 6th Spring, Deceased Status 7th Fall, Deceased Status 8th Fall, Deceased Status 9th Fall, Deceased Status 9th Spring, Deceased Status5th Spring, Deceased Status7th Spring, Deceased Status8th Spring, Degree 1st Fall, Degree 1st Spring, Degree 2nd Fall, Degree 2nd Spring, Degree 3rd Fall, Degree 3rd Spring, Degree 4th Fall, Degree 4th Spring, Degree 5th Fall, Degree 6th Fall, Degree 6th Spring, Degree 7th Fall, Degree 8th Fall, Degree 9th Fall, Degree 9th Spring, Degree5th Spring, Degree7th Spring, Degree8th Spring, Gender Desc, INDI in Academic Period Starting Fall 2025 1st Fall, INDI in Academic Period Starting Fall 2025 1st Spring, INDI in Academic Period Starting Fall 2025 2nd Fall, INDI in Academic Period Starting Fall 2025 2nd Spring, INDI in Academic Period Starting Fall 2025 3rd Fall, INDI in Academic Period Starting Fall 2025 3rd Spring, INDI in Academic Period Starting Fall 2025 4th Fall, INDI in Academic Period Starting Fall 2025 4th Spring, INDI in Academic Period Starting Fall 2025 5th Fall, INDI in Academic Period Starting Fall 2025 6th Fall, INDI in Academic Period Starting Fall 2025 6th Spring, INDI in Academic Period Starting Fall 2025 7th Fall, INDI in Academic Period Starting Fall 2025 8th Fall, INDI in Academic Period Starting Fall 2025 9th Fall, INDI in Academic Period Starting Fall 2025 9th Spring, INDI in Academic Period Starting Fall 20255th Spring, INDI in Academic Period Starting Fall 20257th Spring, INDI in Academic Period Starting Fall 20258th Spring, Nation Of Citizenship Desc 1st Fall, Nation Of Citizenship Desc 1st Spring, Nation Of Citizenship Desc 2nd Fall, Nation Of Citizenship Desc 2nd Spring, Nation Of Citizenship Desc 3rd Fall, Nation Of Citizenship Desc 3rd Spring, Nation Of Citizenship Desc 4th Fall, Nation Of Citizenship Desc 4th Spring, Nation Of Citizenship Desc 5th  ...
# Index: []
#
# [0 rows x 642 columns]

# %%
dfp[dfp['ID'].isin(dfe_t2b['ID'])]
# Out:
#               ID AID_YEAR
# 10414  101704893     2223
# 11470  101704893     2324
# 12592  101704893     2425
# 12622  101713264     2425
# 12629  101714314     2425
# 13787  101704893     2526
# 13798  101713264     2526
# 13805  101714314     2526

# %%
dfr[dfr['Person Uid']=="1925664"]
# Out:
#       Academic Period 1st Fall Academic Period 1st Spring  \
# 23585                   202280                     202310
#
#       Academic Period 2nd Fall Academic Period 2nd Spring  \
# 23585                   202380                     202410
#
#       Academic Period 3rd Fall Academic Period 3rd Spring  \
# 23585                   202480                     202510
#
#       Academic Period 4th Fall Academic Period 4th Spring  \
# 23585                   202580                        NaN
#
#       Academic Period 5th Fall Academic Period 6th Fall  \
# 23585                      NaN                      NaN
#
#       Academic Period 6th Spring Academic Period 7th Fall  \
# 23585                        NaN                      NaN
#
#       Academic Period 8th Fall Academic Period 9th Fall  \
# 23585                      NaN                      NaN
#
#       Academic Period 9th Spring Academic Period Graduation  \
# 23585                        NaN                        NaN
#
#       Academic Period5th Spring Academic Period7th Spring  \
# 23585                       NaN                       NaN
#
#       Academic Period8th Spring Academic Standing Desc 1st Fall  \
# 23585                       NaN                  Not Calculated
#
#       Academic Standing Desc 1st Spring Academic Standing Desc 2nd Fall  \
# 23585                     Good Standing                   Good Standing
#
#       Academic Standing Desc 2nd Spring Academic Standing Desc 3rd Fall  \
# 23585                     Good Standing                   Good Standing
#
#       Academic Standing Desc 3rd Spring Academic Standing Desc 4th Fall  \
# 23585                     Good Standing                   Good Standing
#
#       Academic Standing Desc 4th Spring Academic Standing Desc 5th Fall  \
# 23585                               NaN                             NaN
#
#       Academic Standing Desc 6th Fall Academic Standing Desc 6th Spring  \
# 23585                             NaN                               NaN
#
#       Academic Standing Desc 7th Fall Academic Standing Desc 8th Fall  \
# 23585                             NaN                             NaN
#
#       Academic Standing Desc 9th Fall Academic Standing Desc 9th Spring  \
# 23585                             NaN                               NaN
#
#       Academic Standing Desc5th Spring Academic Standing Desc7th Spring  \
# 23585                              NaN                              NaN
#
#       Academic Standing Desc8th Spring Cohort Cohort Academic Period  \
# 23585                              NaN  22FED                 202280
#
#                         Cohort Desc Cohort Fiscal Year  \
# 23585  2022 Fall 1st Year Full-Time               2023
#
#                             Cohort Name Cohort Season  \
# 23585  2022 Fall, First-Time, Full-Time          Fall
#
#       Cohort Start Date (for IPEDS Graduation Versions)  \
# 23585                                         8/31/2022
#
#       Cohort Start Term Name Cohort Start Terms Cohort Time Status  \
# 23585              Fall 2022             202280                NaN
#
#       Cohort Transfer Status Cohort Type      Cohort Type Description  ...  \
# 23585             First-Time         FED  Fall, First-Time, Full-Time  ...
#
#       Retained to or graduated before 4th year from 3rd year (excludes students not retained to 3rd year)  \
# 23585                                                  1
#
#       Retained to or graduated before 4th Year Spring  \
# 23585                                             NaN
#
#       Retained to or graduated before 5th Year  \
# 23585                                      NaN
#
#       Retained to or graduated before 5th Year Spring  \
# 23585                                             NaN
#
#       Retained to or graduated before 6th Year  \
# 23585                                      NaN
#
#       Retained to or graduated before 6th Year Spring  \
# 23585                                             NaN
#
#       Retained to or graduated before 7th Year  \
# 23585                                      NaN
#
#       Retained to or graduated before 7th Year Spring  \
# 23585                                             NaN
#
#       Retained to or graduated before 8th Year  \
# 23585                                      NaN
#
#       Spring Adjusted to Years to Graduation for Retention Measure  \
# 23585                                                NaN
#
#       Term Updated for Graduation  \
# 23585                      202553
#
#       Term Updated for Graduation - Cohort Start Term  \
# 23585                                             273
#
#       Trans Credit Earned Cumulative 1st Fall  \
# 23585                                      18
#
#       Trans Credit Earned Cumulative 1st Spring  \
# 23585                                        39
#
#       Trans Credit Earned Cumulative 2nd Fall  \
# 23585                                      39
#
#       Trans Credit Earned Cumulative 2nd Spring  \
# 23585                                        39
#
#       Trans Credit Earned Cumulative 3rd Fall  \
# 23585                                      39
#
#       Trans Credit Earned Cumulative 3rd Spring  \
# 23585                                        39
#
#       Trans Credit Earned Cumulative 4th Fall  \
# 23585                                     NaN
#
#       Trans Credit Earned Cumulative 4th Spring  \
# 23585                                       NaN
#
#       Trans Credit Earned Cumulative 5th Fall  \
# 23585                                     NaN
#
#       Trans Credit Earned Cumulative 6th Fall  \
# 23585                                     NaN
#
#       Trans Credit Earned Cumulative 6th Spring  \
# 23585                                       NaN
#
#       Trans Credit Earned Cumulative 7th Fall  \
# 23585                                     NaN
#
#       Trans Credit Earned Cumulative 8th Fall  \
# 23585                                     NaN
#
#       Trans Credit Earned Cumulative 9th Fall  \
# 23585                                     NaN
#
#       Trans Credit Earned Cumulative 9th Spring  \
# 23585                                       NaN
#
#       Trans Credit Earned Cumulative5th Spring  \
# 23585                                      NaN
#
#       Trans Credit Earned Cumulative7th Spring  \
# 23585                                      NaN
#
#       Trans Credit Earned Cumulative8th Spring University Honors Program  \
# 23585                                      NaN                         2
#
#       University Honors Program 1st Fall University Honors Program 1st Spring  \
# 23585                                  1                                    1
#
#       University Honors Program 2nd Fall University Honors Program 2nd Spring  \
# 23585                                NaN                                  NaN
#
#       University Honors Program 3rd Fall University Honors Program 3rd Spring  \
# 23585                                NaN                                  NaN
#
#       University Honors Program 4th Fall University Honors Program 4th Spring  \
# 23585                                NaN                                  NaN
#
#       University Honors Program 5th Fall University Honors Program 6th Fall  \
# 23585                                NaN                                NaN
#
#       University Honors Program 6th Spring University Honors Program 7th Fall  \
# 23585                                  NaN                                NaN
#
#       University Honors Program 8th Fall University Honors Program 9th Fall  \
# 23585                                NaN                                NaN
#
#       University Honors Program 9th Spring  \
# 23585                                  NaN
#
#       University Honors Program5th Spring University Honors Program7th Spring  \
# 23585                                 NaN                                 NaN
#
#       University Honors Program8th Spring Years to Graduation
# 23585                                 NaN                 NaN
#
# [1 rows x 642 columns]

# %%
enrollment_conditions = (
        (dfe['Academic Period'] == term) &
        (dfe['Time Status'] == 'FT') &
        (dfe['Student Level'] == 'UG') &
        (dfe['Degree'] != 'Non Degree')
    )

aid_year = calc_academic_year_from_term(term) 
incoming_transfer_cohort = term[0:4] + " " + "Fall, Transfer, Full-Time"

pids = dfp.loc[dfp['AID_YEAR'] == aid_year, id_column].dropna()
eids = dfe.loc[enrollment_conditions, id_column].dropna()
rids = dfr.loc[dfr['Cohort Name'] != incoming_transfer_cohort, id_column].dropna()
rids_t = dfr.loc[dfr['Cohort Name'] == incoming_transfer_cohort, id_column].dropna()

# %%
len(set(eids))
# Out:
# 6939

# %%
len(set(eids) & set(rids))
# Out:
# 6764

# %%
len(set(rids))
# Out:
# 28841

# %%
len(set(rids_t))
# Out:
# 163

# %%
len(set(eids)) - len(set(rids_t))
# Out:
# 6776

# %%
len(set(pids) & set(eids)) - len(set(pids) & set(eids) & set(rids_t))
# Out:
# 1217

# %%
len(set(rids_t) & set(pids))
# Out:
# 54

# %%
len(set(rids) & set(pids))
# Out:
# 1253

# %%
len(set(pids)) - len(set(pids) & set(eids) & set(rids_t))
# Out:
# 1256

# %%
n_pell_intr = len(set(pids) & set(eids) & set(rids_t))

# %%
n_pell_intr
# Out:
# 54

# %%
len(set(pids) & set(eids)) - n_pell_intr
# Out:
# 1217

# %%
len(set(pids) & set(eids))
# Out:
# 1271
